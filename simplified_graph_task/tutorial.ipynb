# %% [markdown]
# # Step 1. get synthetic graph dataset
#
# Here we use path finding task as an example

# %%
from generate_graphs import get_sync_graph_data
base_model_path=f'/egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/datasets'
max_num = 1000000
method = 'path'
n = 10
pattern_name = f'sync{n}'
edge_remove = True
edge_remove_density = 0.4
density = 0.8
get_sync_graph_data(base_model_path, max_num,method,n,density,pattern_name,edge_remove,edge_remove_density)
# Out:
# Density=0.8, edge_num=72
# generating: 22 goal: 1000000 max path length 5
# generating: 51 goal: 1000000 max path length 5
# generating: 70 goal: 1000000 max path length 5
# generating: 90 goal: 1000000 max path length 5
# generating: 124 goal: 1000000 max path length 5
# generating: 143 goal: 1000000 max path length 5
# generating: 165 goal: 1000000 max path length 5
# generating: 176 goal: 1000000 max path length 5
# generating: 192 goal: 1000000 max path length 5
# generating: 209 goal: 1000000 max path length 5
# generating: 224 goal: 1000000 max path length 6
# generating: 242 goal: 1000000 max path length 6
# generating: 258 goal: 1000000 max path length 6
# generating: 281 goal: 1000000 max path length 6
# generating: 304 goal: 1000000 max path length 6
# generating: 333 goal: 1000000 max path length 6
# generating: 346 goal: 1000000 max path length 6
# generating: 363 goal: 1000000 max path length 6
# generating: 378 goal: 1000000 max path length 6
# generating: 391 goal: 1000000 max path length 6
# generating: 413 goal: 1000000 max path length 6
# generating: 435 goal: 1000000 max path length 6
# generating: 446 goal: 1000000 max path length 6
# generating: 466 goal: 1000000 max path length 6
# generating: 480 goal: 1000000 max path length 6
# generating: 503 goal: 1000000 max path length 6
# generating: 513 goal: 1000000 max path length 6
# generating: 535 goal: 1000000 max path length 6
# generating: 564 goal: 1000000 max path length 6
# generating: 585 goal: 1000000 max path length 6
# generating: 614 goal: 1000000 max path length 6
# generating: 626 goal: 1000000 max path length 6
# generating: 665 goal: 1000000 max path length 6
# generating: 674 goal: 1000000 max path length 6
# generating: 697 goal: 1000000 max path length 6
# generating: 723 goal: 1000000 max path length 7
# generating: 742 goal: 1000000 max path length 7
# generating: 772 goal: 1000000 max path length 7
# generating: 790 goal: 1000000 max path length 7
# generating: 816 goal: 1000000 max path length 7
# generating: 848 goal: 1000000 max path length 7
# generating: 863 goal: 1000000 max path length 7
# generating: 880 goal: 1000000 max path length 7
# generating: 894 goal: 1000000 max path length 7
# generating: 908 goal: 1000000 max path length 7
# generating: 922 goal: 1000000 max path length 7
# generating: 941 goal: 1000000 max path length 7
# generating: 970 goal: 1000000 max path length 7
# generating: 985 goal: 1000000 max path length 7
# generating: 1015 goal: 1000000 max path length 7
# generating: 1036 goal: 1000000 max path length 7
# generating: 1058 goal: 1000000 max path length 7
# generating: 1086 goal: 1000000 max path length 7
# generating: 1113 goal: 1000000 max path length 7
# generating: 1133 goal: 1000000 max path length 7
# generating: 1168 goal: 1000000 max path length 7
# generating: 1184 goal: 1000000 max path length 7
# generating: 1210 goal: 1000000 max path length 7
# generating: 1228 goal: 1000000 max path length 7
# generating: 1258 goal: 1000000 max path length 7
# generating: 1276 goal: 1000000 max path length 7
# generating: 1306 goal: 1000000 max path length 7
# generating: 1332 goal: 1000000 max path length 7
# generating: 1359 goal: 1000000 max path length 7
# generating: 1383 goal: 1000000 max path length 7
# generating: 1398 goal: 1000000 max path length 7
# generating: 1414 goal: 1000000 max path length 7
# generating: 1440 goal: 1000000 max path length 7
# generating: 1458 goal: 1000000 max path length 7
# generating: 1477 goal: 1000000 max path length 7
# generating: 1493 goal: 1000000 max path length 7
# generating: 1526 goal: 1000000 max path length 7
# generating: 1547 goal: 1000000 max path length 7
# generating: 1571 goal: 1000000 max path length 7
# generating: 1592 goal: 1000000 max path length 7
# generating: 1607 goal: 1000000 max path length 7
# generating: 1623 goal: 1000000 max path length 7
# generating: 1634 goal: 1000000 max path length 7
# generating: 1653 goal: 1000000 max path length 7
# generating: 1676 goal: 1000000 max path length 7
# generating: 1699 goal: 1000000 max path length 7
# generating: 1718 goal: 1000000 max path length 7
# generating: 1743 goal: 1000000 max path length 7
# generating: 1767 goal: 1000000 max path length 7
# generating: 1790 goal: 1000000 max path length 7
# generating: 1806 goal: 1000000 max path length 7
# generating: 1844 goal: 1000000 max path length 7
# generating: 1860 goal: 1000000 max path length 7
# generating: 1880 goal: 1000000 max path length 7
# generating: 1897 goal: 1000000 max path length 7
# generating: 1920 goal: 1000000 max path length 7
# generating: 1946 goal: 1000000 max path length 7
# generating: 1968 goal: 1000000 max path length 7
# generating: 1985 goal: 1000000 max path length 7
# generating: 2006 goal: 1000000 max path length 7
# generating: 2038 goal: 1000000 max path length 7
# generating: 2060 goal: 1000000 max path length 7
# generating: 2081 goal: 1000000 max path length 7
# generating: 2099 goal: 1000000 max path length 7
# generating: 2124 goal: 1000000 max path length 7
# generating: 2151 goal: 1000000 max path length 7
# generating: 2186 goal: 1000000 max path length 7
# generating: 2205 goal: 1000000 max path length 7
# generating: 2230 goal: 1000000 max path length 7
# generating: 2247 goal: 1000000 max path length 7
# generating: 2262 goal: 1000000 max path length 7
# generating: 2280 goal: 1000000 max path length 7
# generating: 2306 goal: 1000000 max path length 7
# generating: 2328 goal: 1000000 max path length 7
# generating: 2358 goal: 1000000 max path length 7
# generating: 2376 goal: 1000000 max path length 7
# generating: 2393 goal: 1000000 max path length 7
# generating: 2412 goal: 1000000 max path length 7
# generating: 2437 goal: 1000000 max path length 7
# generating: 2457 goal: 1000000 max path length 7
# generating: 2478 goal: 1000000 max path length 7
# generating: 2515 goal: 1000000 max path length 7
# generating: 2538 goal: 1000000 max path length 7
# generating: 2558 goal: 1000000 max path length 7
# generating: 2581 goal: 1000000 max path length 7
# generating: 2603 goal: 1000000 max path length 7
# generating: 2623 goal: 1000000 max path length 7
# generating: 2646 goal: 1000000 max path length 7
# generating: 2663 goal: 1000000 max path length 7
# generating: 2695 goal: 1000000 max path length 7
# generating: 2717 goal: 1000000 max path length 7
# generating: 2741 goal: 1000000 max path length 7
# generating: 2762 goal: 1000000 max path length 7
# generating: 2783 goal: 1000000 max path length 7
# generating: 2801 goal: 1000000 max path length 7
# generating: 2816 goal: 1000000 max path length 7
# generating: 2842 goal: 1000000 max path length 7
# generating: 2871 goal: 1000000 max path length 7
# generating: 2890 goal: 1000000 max path length 7
# generating: 2914 goal: 1000000 max path length 7
# generating: 2936 goal: 1000000 max path length 7
# generating: 2956 goal: 1000000 max path length 7
# generating: 2971 goal: 1000000 max path length 7
# generating: 2992 goal: 1000000 max path length 7
# generating: 3018 goal: 1000000 max path length 7
# generating: 3045 goal: 1000000 max path length 7
# generating: 3069 goal: 1000000 max path length 7
# generating: 3089 goal: 1000000 max path length 7
# generating: 3112 goal: 1000000 max path length 7
# generating: 3136 goal: 1000000 max path length 7
# generating: 3154 goal: 1000000 max path length 7
# generating: 3177 goal: 1000000 max path length 7
# generating: 3194 goal: 1000000 max path length 7
# generating: 3217 goal: 1000000 max path length 7
# generating: 3235 goal: 1000000 max path length 7
# generating: 3252 goal: 1000000 max path length 7
# generating: 3266 goal: 1000000 max path length 7
# generating: 3290 goal: 1000000 max path length 7
# generating: 3312 goal: 1000000 max path length 7
# generating: 3329 goal: 1000000 max path length 7
# generating: 3350 goal: 1000000 max path length 7
# generating: 3374 goal: 1000000 max path length 7
# generating: 3391 goal: 1000000 max path length 7
# generating: 3411 goal: 1000000 max path length 7
# generating: 3433 goal: 1000000 max path length 7
# generating: 3452 goal: 1000000 max path length 7
# generating: 3470 goal: 1000000 max path length 7
# generating: 3489 goal: 1000000 max path length 7
# generating: 3513 goal: 1000000 max path length 7
# generating: 3530 goal: 1000000 max path length 7
# generating: 3556 goal: 1000000 max path length 7
# generating: 3577 goal: 1000000 max path length 7
# generating: 3588 goal: 1000000 max path length 7
# generating: 3630 goal: 1000000 max path length 7
# generating: 3655 goal: 1000000 max path length 7
# generating: 3678 goal: 1000000 max path length 7
# generating: 3701 goal: 1000000 max path length 7
# generating: 3716 goal: 1000000 max path length 7
# generating: 3737 goal: 1000000 max path length 7
# generating: 3748 goal: 1000000 max path length 7
# generating: 3764 goal: 1000000 max path length 7
# generating: 3794 goal: 1000000 max path length 7
# generating: 3818 goal: 1000000 max path length 7
# generating: 3845 goal: 1000000 max path length 7
# generating: 3868 goal: 1000000 max path length 7
# generating: 3891 goal: 1000000 max path length 7
# generating: 3905 goal: 1000000 max path length 7
# generating: 3927 goal: 1000000 max path length 7
# generating: 3951 goal: 1000000 max path length 7
# generating: 3974 goal: 1000000 max path length 7
# generating: 4001 goal: 1000000 max path length 7
# generating: 4022 goal: 1000000 max path length 7
# generating: 4034 goal: 1000000 max path length 7
# generating: 4049 goal: 1000000 max path length 7
# generating: 4068 goal: 1000000 max path length 7
# generating: 4089 goal: 1000000 max path length 7
# generating: 4104 goal: 1000000 max path length 7
# generating: 4124 goal: 1000000 max path length 7
# generating: 4146 goal: 1000000 max path length 7
# generating: 4176 goal: 1000000 max path length 7
# generating: 4200 goal: 1000000 max path length 7
# generating: 4223 goal: 1000000 max path length 7
# generating: 4234 goal: 1000000 max path length 7
# generating: 4249 goal: 1000000 max path length 7
# generating: 4270 goal: 1000000 max path length 7
# generating: 4307 goal: 1000000 max path length 7
# generating: 4323 goal: 1000000 max path length 7
# generating: 4355 goal: 1000000 max path length 7
# generating: 4368 goal: 1000000 max path length 7
# generating: 4383 goal: 1000000 max path length 7
# generating: 4402 goal: 1000000 max path length 7
# generating: 4410 goal: 1000000 max path length 7
# generating: 4420 goal: 1000000 max path length 7
# generating: 4438 goal: 1000000 max path length 7
# generating: 4456 goal: 1000000 max path length 7
# generating: 4474 goal: 1000000 max path length 7
# generating: 4504 goal: 1000000 max path length 7
# generating: 4529 goal: 1000000 max path length 7
# generating: 4550 goal: 1000000 max path length 7
# generating: 4565 goal: 1000000 max path length 7
# generating: 4578 goal: 1000000 max path length 7
# generating: 4601 goal: 1000000 max path length 7
# generating: 4619 goal: 1000000 max path length 7
# generating: 4638 goal: 1000000 max path length 7
# generating: 4672 goal: 1000000 max path length 7
# generating: 4698 goal: 1000000 max path length 7
# generating: 4720 goal: 1000000 max path length 7
# generating: 4738 goal: 1000000 max path length 7
# generating: 4756 goal: 1000000 max path length 7
# generating: 4781 goal: 1000000 max path length 7
# generating: 4799 goal: 1000000 max path length 7
# generating: 4821 goal: 1000000 max path length 7
# generating: 4834 goal: 1000000 max path length 7
# generating: 4850 goal: 1000000 max path length 7
# generating: 4872 goal: 1000000 max path length 7
# generating: 4886 goal: 1000000 max path length 7
# generating: 4895 goal: 1000000 max path length 7
# generating: 4918 goal: 1000000 max path length 7
# generating: 4937 goal: 1000000 max path length 7
# generating: 4957 goal: 1000000 max path length 7
# generating: 4980 goal: 1000000 max path length 7
# generating: 5011 goal: 1000000 max path length 7
# generating: 5031 goal: 1000000 max path length 7
# generating: 5054 goal: 1000000 max path length 7
# generating: 5076 goal: 1000000 max path length 7
# generating: 5101 goal: 1000000 max path length 7
# generating: 5124 goal: 1000000 max path length 7
# generating: 5146 goal: 1000000 max path length 7
# generating: 5159 goal: 1000000 max path length 7
# generating: 5185 goal: 1000000 max path length 7
# generating: 5205 goal: 1000000 max path length 7
# generating: 5231 goal: 1000000 max path length 7
# generating: 5261 goal: 1000000 max path length 7
# generating: 5285 goal: 1000000 max path length 7
# generating: 5310 goal: 1000000 max path length 7
# generating: 5329 goal: 1000000 max path length 7
# generating: 5343 goal: 1000000 max path length 7
# generating: 5357 goal: 1000000 max path length 7
# generating: 5377 goal: 1000000 max path length 7
# generating: 5393 goal: 1000000 max path length 7
# generating: 5412 goal: 1000000 max path length 7
# generating: 5434 goal: 1000000 max path length 7
# generating: 5455 goal: 1000000 max path length 7
# generating: 5482 goal: 1000000 max path length 7
# generating: 5507 goal: 1000000 max path length 7
# generating: 5523 goal: 1000000 max path length 7
# generating: 5539 goal: 1000000 max path length 7
# generating: 5564 goal: 1000000 max path length 7
# generating: 5577 goal: 1000000 max path length 7
# generating: 5603 goal: 1000000 max path length 7
# generating: 5615 goal: 1000000 max path length 7
# generating: 5640 goal: 1000000 max path length 7
# generating: 5653 goal: 1000000 max path length 7
# generating: 5682 goal: 1000000 max path length 7
# generating: 5709 goal: 1000000 max path length 7
# generating: 5729 goal: 1000000 max path length 7
# generating: 5745 goal: 1000000 max path length 7
# generating: 5773 goal: 1000000 max path length 7
# generating: 5789 goal: 1000000 max path length 7
# generating: 5812 goal: 1000000 max path length 7
# generating: 5827 goal: 1000000 max path length 7
# generating: 5847 goal: 1000000 max path length 7
# generating: 5865 goal: 1000000 max path length 7
# generating: 5887 goal: 1000000 max path length 7
# generating: 5906 goal: 1000000 max path length 7
# generating: 5928 goal: 1000000 max path length 7
# generating: 5947 goal: 1000000 max path length 7
# generating: 5964 goal: 1000000 max path length 7
# generating: 5980 goal: 1000000 max path length 7
# generating: 6005 goal: 1000000 max path length 7
# generating: 6023 goal: 1000000 max path length 7
# generating: 6042 goal: 1000000 max path length 7
# generating: 6057 goal: 1000000 max path length 7
# generating: 6069 goal: 1000000 max path length 7
# generating: 6085 goal: 1000000 max path length 7
# generating: 6122 goal: 1000000 max path length 7
# generating: 6145 goal: 1000000 max path length 7
# generating: 6166 goal: 1000000 max path length 7
# generating: 6196 goal: 1000000 max path length 7
# generating: 6211 goal: 1000000 max path length 7
# generating: 6223 goal: 1000000 max path length 7
# generating: 6246 goal: 1000000 max path length 7
# generating: 6262 goal: 1000000 max path length 7
# generating: 6287 goal: 1000000 max path length 7
# generating: 6310 goal: 1000000 max path length 7
# generating: 6328 goal: 1000000 max path length 7
# generating: 6353 goal: 1000000 max path length 7
# generating: 6380 goal: 1000000 max path length 7
# generating: 6396 goal: 1000000 max path length 7
# generating: 6409 goal: 1000000 max path length 7
# generating: 6429 goal: 1000000 max path length 7
# generating: 6456 goal: 1000000 max path length 7
# generating: 6472 goal: 1000000 max path length 7
# generating: 6490 goal: 1000000 max path length 7
# generating: 6514 goal: 1000000 max path length 7
# generating: 6534 goal: 1000000 max path length 7
# generating: 6552 goal: 1000000 max path length 7
# generating: 6576 goal: 1000000 max path length 7
# generating: 6597 goal: 1000000 max path length 7
# generating: 6608 goal: 1000000 max path length 7
# generating: 6618 goal: 1000000 max path length 7
# generating: 6650 goal: 1000000 max path length 7
# generating: 6663 goal: 1000000 max path length 7
# generating: 6685 goal: 1000000 max path length 7
# generating: 6713 goal: 1000000 max path length 7
# generating: 6737 goal: 1000000 max path length 7
# generating: 6761 goal: 1000000 max path length 7
# generating: 6769 goal: 1000000 max path length 7
# generating: 6793 goal: 1000000 max path length 7
# generating: 6815 goal: 1000000 max path length 7
# generating: 6838 goal: 1000000 max path length 7
# generating: 6857 goal: 1000000 max path length 7
# generating: 6877 goal: 1000000 max path length 7
# generating: 6899 goal: 1000000 max path length 7
# generating: 6925 goal: 1000000 max path length 7
# generating: 6950 goal: 1000000 max path length 7
# generating: 6961 goal: 1000000 max path length 7
# generating: 6990 goal: 1000000 max path length 7
# generating: 7007 goal: 1000000 max path length 7
# generating: 7025 goal: 1000000 max path length 7
# generating: 7041 goal: 1000000 max path length 7
# generating: 7059 goal: 1000000 max path length 7
# generating: 7086 goal: 1000000 max path length 7
# generating: 7114 goal: 1000000 max path length 7
# generating: 7134 goal: 1000000 max path length 7
# generating: 7158 goal: 1000000 max path length 7
# generating: 7181 goal: 1000000 max path length 7
# generating: 7199 goal: 1000000 max path length 7
# generating: 7222 goal: 1000000 max path length 7
# generating: 7238 goal: 1000000 max path length 7
# generating: 7249 goal: 1000000 max path length 7
# generating: 7267 goal: 1000000 max path length 7
# generating: 7293 goal: 1000000 max path length 7
# generating: 7312 goal: 1000000 max path length 7
# generating: 7339 goal: 1000000 max path length 7
# generating: 7356 goal: 1000000 max path length 7
# generating: 7385 goal: 1000000 max path length 7
# generating: 7403 goal: 1000000 max path length 7
# generating: 7425 goal: 1000000 max path length 7
# generating: 7450 goal: 1000000 max path length 7
# generating: 7476 goal: 1000000 max path length 7
# generating: 7491 goal: 1000000 max path length 7
# generating: 7511 goal: 1000000 max path length 7
# generating: 7541 goal: 1000000 max path length 7
# generating: 7569 goal: 1000000 max path length 7
# generating: 7589 goal: 1000000 max path length 7
# generating: 7620 goal: 1000000 max path length 7
# generating: 7636 goal: 1000000 max path length 7
# generating: 7662 goal: 1000000 max path length 7
# generating: 7683 goal: 1000000 max path length 7
# generating: 7705 goal: 1000000 max path length 7
# generating: 7724 goal: 1000000 max path length 7
# generating: 7751 goal: 1000000 max path length 7
# generating: 7774 goal: 1000000 max path length 7
# generating: 7790 goal: 1000000 max path length 7
# generating: 7825 goal: 1000000 max path length 7
# generating: 7855 goal: 1000000 max path length 7
# generating: 7870 goal: 1000000 max path length 7
# generating: 7894 goal: 1000000 max path length 7
# generating: 7914 goal: 1000000 max path length 7
# generating: 7935 goal: 1000000 max path length 7
# generating: 7965 goal: 1000000 max path length 7
# generating: 7994 goal: 1000000 max path length 7
# generating: 8020 goal: 1000000 max path length 7
# generating: 8052 goal: 1000000 max path length 7
# generating: 8075 goal: 1000000 max path length 7
# generating: 8091 goal: 1000000 max path length 7
# generating: 8106 goal: 1000000 max path length 7
# generating: 8130 goal: 1000000 max path length 7
# generating: 8160 goal: 1000000 max path length 7
# generating: 8193 goal: 1000000 max path length 7
# generating: 8216 goal: 1000000 max path length 7
# generating: 8234 goal: 1000000 max path length 7
# generating: 8251 goal: 1000000 max path length 7
# generating: 8275 goal: 1000000 max path length 7
# generating: 8297 goal: 1000000 max path length 7
# generating: 8312 goal: 1000000 max path length 7
# generating: 8336 goal: 1000000 max path length 7
# generating: 8357 goal: 1000000 max path length 7
# generating: 8380 goal: 1000000 max path length 7
# generating: 8404 goal: 1000000 max path length 7
# generating: 8418 goal: 1000000 max path length 7
# generating: 8445 goal: 1000000 max path length 7
# generating: 8463 goal: 1000000 max path length 7
# generating: 8486 goal: 1000000 max path length 7
# generating: 8511 goal: 1000000 max path length 7
# generating: 8528 goal: 1000000 max path length 7
# generating: 8553 goal: 1000000 max path length 7
# generating: 8565 goal: 1000000 max path length 7
# generating: 8579 goal: 1000000 max path length 7
# generating: 8592 goal: 1000000 max path length 7
# generating: 8619 goal: 1000000 max path length 7
# generating: 8629 goal: 1000000 max path length 7
# generating: 8660 goal: 1000000 max path length 7
# generating: 8680 goal: 1000000 max path length 7
# generating: 8693 goal: 1000000 max path length 7
# generating: 8719 goal: 1000000 max path length 7
# generating: 8739 goal: 1000000 max path length 7
# generating: 8756 goal: 1000000 max path length 7
# generating: 8767 goal: 1000000 max path length 7
# generating: 8790 goal: 1000000 max path length 7
# generating: 8808 goal: 1000000 max path length 7
# generating: 8828 goal: 1000000 max path length 7
# generating: 8858 goal: 1000000 max path length 7
# generating: 8879 goal: 1000000 max path length 7
# generating: 8908 goal: 1000000 max path length 7
# generating: 8930 goal: 1000000 max path length 7
# generating: 8953 goal: 1000000 max path length 7
# generating: 8983 goal: 1000000 max path length 7
# generating: 9011 goal: 1000000 max path length 7
# generating: 9031 goal: 1000000 max path length 7
# generating: 9052 goal: 1000000 max path length 7
# generating: 9070 goal: 1000000 max path length 7
# generating: 9084 goal: 1000000 max path length 7
# generating: 9103 goal: 1000000 max path length 7
# generating: 9129 goal: 1000000 max path length 7
# generating: 9159 goal: 1000000 max path length 7
# generating: 9180 goal: 1000000 max path length 7
# generating: 9214 goal: 1000000 max path length 7
# generating: 9235 goal: 1000000 max path length 7
# generating: 9253 goal: 1000000 max path length 7
# generating: 9278 goal: 1000000 max path length 7
# generating: 9292 goal: 1000000 max path length 7
# generating: 9311 goal: 1000000 max path length 7
# generating: 9325 goal: 1000000 max path length 7
# generating: 9347 goal: 1000000 max path length 7
# generating: 9374 goal: 1000000 max path length 7
# generating: 9393 goal: 1000000 max path length 9
# generating: 9411 goal: 1000000 max path length 9
# generating: 9432 goal: 1000000 max path length 9
# generating: 9456 goal: 1000000 max path length 9
# generating: 9470 goal: 1000000 max path length 9
# generating: 9487 goal: 1000000 max path length 9
# generating: 9507 goal: 1000000 max path length 9
# generating: 9537 goal: 1000000 max path length 9
# generating: 9551 goal: 1000000 max path length 9
# generating: 9580 goal: 1000000 max path length 9
# generating: 9602 goal: 1000000 max path length 9
# generating: 9621 goal: 1000000 max path length 9
# generating: 9635 goal: 1000000 max path length 9
# generating: 9642 goal: 1000000 max path length 9
# generating: 9671 goal: 1000000 max path length 9
# generating: 9692 goal: 1000000 max path length 9
# generating: 9719 goal: 1000000 max path length 9
# generating: 9736 goal: 1000000 max path length 9
# generating: 9756 goal: 1000000 max path length 9
# generating: 9777 goal: 1000000 max path length 9
# generating: 9791 goal: 1000000 max path length 9
# generating: 9821 goal: 1000000 max path length 9
# generating: 9842 goal: 1000000 max path length 9
# generating: 9852 goal: 1000000 max path length 9
# generating: 9875 goal: 1000000 max path length 9
# generating: 9896 goal: 1000000 max path length 9
# generating: 9917 goal: 1000000 max path length 9
# generating: 9924 goal: 1000000 max path length 9
# generating: 9953 goal: 1000000 max path length 9
# generating: 9961 goal: 1000000 max path length 9
# generating: 9976 goal: 1000000 max path length 9
# generating: 9994 goal: 1000000 max path length 9
# generating: 10011 goal: 1000000 max path length 9
# generating: 10033 goal: 1000000 max path length 9
# generating: 10058 goal: 1000000 max path length 9
# generating: 10069 goal: 1000000 max path length 9
# generating: 10096 goal: 1000000 max path length 9
# generating: 10125 goal: 1000000 max path length 9
# generating: 10142 goal: 1000000 max path length 9
# generating: 10167 goal: 1000000 max path length 9
# generating: 10182 goal: 1000000 max path length 9
# generating: 10209 goal: 1000000 max path length 9
# generating: 10224 goal: 1000000 max path length 9
# generating: 10251 goal: 1000000 max path length 9
# generating: 10270 goal: 1000000 max path length 9
# generating: 10284 goal: 1000000 max path length 9
# generating: 10300 goal: 1000000 max path length 9
# generating: 10312 goal: 1000000 max path length 9
# generating: 10349 goal: 1000000 max path length 9
# generating: 10369 goal: 1000000 max path length 9
# generating: 10393 goal: 1000000 max path length 9
# generating: 10414 goal: 1000000 max path length 9
# generating: 10438 goal: 1000000 max path length 9
# generating: 10467 goal: 1000000 max path length 9
# generating: 10496 goal: 1000000 max path length 9
# generating: 10509 goal: 1000000 max path length 9
# generating: 10538 goal: 1000000 max path length 9
# generating: 10562 goal: 1000000 max path length 9
# generating: 10583 goal: 1000000 max path length 9
# generating: 10613 goal: 1000000 max path length 9
# generating: 10632 goal: 1000000 max path length 9
# generating: 10661 goal: 1000000 max path length 9
# generating: 10688 goal: 1000000 max path length 9
# generating: 10705 goal: 1000000 max path length 9
# generating: 10725 goal: 1000000 max path length 9
# generating: 10748 goal: 1000000 max path length 9
# generating: 10775 goal: 1000000 max path length 9
# generating: 10803 goal: 1000000 max path length 9
# generating: 10839 goal: 1000000 max path length 9
# generating: 10861 goal: 1000000 max path length 9
# generating: 10886 goal: 1000000 max path length 9
# generating: 10916 goal: 1000000 max path length 9
# generating: 10934 goal: 1000000 max path length 9
# generating: 10958 goal: 1000000 max path length 9
# generating: 10966 goal: 1000000 max path length 9
# generating: 10975 goal: 1000000 max path length 9
# generating: 11000 goal: 1000000 max path length 9
# generating: 11033 goal: 1000000 max path length 9
# generating: 11053 goal: 1000000 max path length 9
# generating: 11070 goal: 1000000 max path length 9
# generating: 11087 goal: 1000000 max path length 9
# generating: 11114 goal: 1000000 max path length 9
# generating: 11137 goal: 1000000 max path length 9
# generating: 11155 goal: 1000000 max path length 9
# generating: 11176 goal: 1000000 max path length 9
# generating: 11198 goal: 1000000 max path length 9
# generating: 11219 goal: 1000000 max path length 9
# generating: 11238 goal: 1000000 max path length 9
# generating: 11249 goal: 1000000 max path length 9
# generating: 11277 goal: 1000000 max path length 9
# generating: 11309 goal: 1000000 max path length 9
# generating: 11331 goal: 1000000 max path length 9
# generating: 11357 goal: 1000000 max path length 9
# generating: 11374 goal: 1000000 max path length 9
# generating: 11398 goal: 1000000 max path length 9
# generating: 11430 goal: 1000000 max path length 9
# generating: 11447 goal: 1000000 max path length 9
# generating: 11473 goal: 1000000 max path length 9
# generating: 11494 goal: 1000000 max path length 9
# generating: 11513 goal: 1000000 max path length 9
# generating: 11539 goal: 1000000 max path length 9
# generating: 11566 goal: 1000000 max path length 9
# generating: 11588 goal: 1000000 max path length 9
# generating: 11608 goal: 1000000 max path length 9
# generating: 11631 goal: 1000000 max path length 9
# generating: 11649 goal: 1000000 max path length 9
# generating: 11690 goal: 1000000 max path length 9
# generating: 11705 goal: 1000000 max path length 9
# generating: 11735 goal: 1000000 max path length 9
# generating: 11743 goal: 1000000 max path length 9
# generating: 11773 goal: 1000000 max path length 9
# generating: 11804 goal: 1000000 max path length 9
# generating: 11837 goal: 1000000 max path length 9
# generating: 11860 goal: 1000000 max path length 9
# generating: 11885 goal: 1000000 max path length 9
# generating: 11904 goal: 1000000 max path length 9
# generating: 11928 goal: 1000000 max path length 9
# generating: 11957 goal: 1000000 max path length 9
# generating: 11983 goal: 1000000 max path length 9
# generating: 12007 goal: 1000000 max path length 9
# generating: 12018 goal: 1000000 max path length 9
# generating: 12032 goal: 1000000 max path length 9
# generating: 12058 goal: 1000000 max path length 9
# generating: 12072 goal: 1000000 max path length 9
# generating: 12104 goal: 1000000 max path length 9
# generating: 12123 goal: 1000000 max path length 9
# generating: 12148 goal: 1000000 max path length 9
# generating: 12174 goal: 1000000 max path length 9
# generating: 12201 goal: 1000000 max path length 9
# generating: 12221 goal: 1000000 max path length 9
# generating: 12249 goal: 1000000 max path length 9
# generating: 12255 goal: 1000000 max path length 9
# generating: 12270 goal: 1000000 max path length 9
# generating: 12291 goal: 1000000 max path length 9
# generating: 12307 goal: 1000000 max path length 9
# generating: 12328 goal: 1000000 max path length 9
# generating: 12345 goal: 1000000 max path length 9
# generating: 12368 goal: 1000000 max path length 9
# generating: 12393 goal: 1000000 max path length 9
# generating: 12412 goal: 1000000 max path length 9
# generating: 12438 goal: 1000000 max path length 9
# generating: 12467 goal: 1000000 max path length 9
# generating: 12485 goal: 1000000 max path length 9
# generating: 12506 goal: 1000000 max path length 9
# generating: 12526 goal: 1000000 max path length 9
# generating: 12547 goal: 1000000 max path length 9
# generating: 12567 goal: 1000000 max path length 9
# generating: 12590 goal: 1000000 max path length 9
# generating: 12620 goal: 1000000 max path length 9
# generating: 12639 goal: 1000000 max path length 9
# generating: 12666 goal: 1000000 max path length 9
# generating: 12684 goal: 1000000 max path length 9
# generating: 12695 goal: 1000000 max path length 9
# generating: 12712 goal: 1000000 max path length 9
# generating: 12730 goal: 1000000 max path length 9
# generating: 12750 goal: 1000000 max path length 9
# generating: 12776 goal: 1000000 max path length 9
# generating: 12801 goal: 1000000 max path length 9
# generating: 12826 goal: 1000000 max path length 9
# generating: 12851 goal: 1000000 max path length 9
# generating: 12867 goal: 1000000 max path length 9
# generating: 12886 goal: 1000000 max path length 9
# generating: 12913 goal: 1000000 max path length 9
# generating: 12931 goal: 1000000 max path length 9
# generating: 12954 goal: 1000000 max path length 9
# generating: 12974 goal: 1000000 max path length 9
# generating: 12995 goal: 1000000 max path length 9
# generating: 13025 goal: 1000000 max path length 9
# generating: 13050 goal: 1000000 max path length 9
# generating: 13069 goal: 1000000 max path length 9
# generating: 13095 goal: 1000000 max path length 9
# generating: 13119 goal: 1000000 max path length 9
# generating: 13133 goal: 1000000 max path length 9
# generating: 13150 goal: 1000000 max path length 9
# generating: 13169 goal: 1000000 max path length 9
# generating: 13193 goal: 1000000 max path length 9
# generating: 13213 goal: 1000000 max path length 9
# generating: 13233 goal: 1000000 max path length 9
# generating: 13249 goal: 1000000 max path length 9
# generating: 13271 goal: 1000000 max path length 9
# generating: 13289 goal: 1000000 max path length 9
# generating: 13312 goal: 1000000 max path length 9
# generating: 13332 goal: 1000000 max path length 9
# generating: 13352 goal: 1000000 max path length 9
# generating: 13371 goal: 1000000 max path length 9
# generating: 13387 goal: 1000000 max path length 9
# generating: 13405 goal: 1000000 max path length 9
# generating: 13417 goal: 1000000 max path length 9
# generating: 13443 goal: 1000000 max path length 9
# generating: 13461 goal: 1000000 max path length 9
# generating: 13481 goal: 1000000 max path length 9
# generating: 13497 goal: 1000000 max path length 9
# generating: 13513 goal: 1000000 max path length 9
# generating: 13533 goal: 1000000 max path length 9
# generating: 13551 goal: 1000000 max path length 9
# generating: 13577 goal: 1000000 max path length 9
# generating: 13599 goal: 1000000 max path length 9
# generating: 13621 goal: 1000000 max path length 9
# generating: 13641 goal: 1000000 max path length 9
# generating: 13660 goal: 1000000 max path length 9
# generating: 13682 goal: 1000000 max path length 9
# generating: 13694 goal: 1000000 max path length 9
# generating: 13709 goal: 1000000 max path length 9
# generating: 13732 goal: 1000000 max path length 9
# generating: 13756 goal: 1000000 max path length 9
# generating: 13791 goal: 1000000 max path length 9
# generating: 13811 goal: 1000000 max path length 9
# generating: 13839 goal: 1000000 max path length 9
# generating: 13862 goal: 1000000 max path length 9
# generating: 13888 goal: 1000000 max path length 9
# generating: 13907 goal: 1000000 max path length 9
# generating: 13918 goal: 1000000 max path length 9
# generating: 13928 goal: 1000000 max path length 9
# generating: 13948 goal: 1000000 max path length 9
# generating: 13968 goal: 1000000 max path length 9
# generating: 13989 goal: 1000000 max path length 9
# generating: 14009 goal: 1000000 max path length 9
# generating: 14036 goal: 1000000 max path length 9
# generating: 14048 goal: 1000000 max path length 9
# generating: 14071 goal: 1000000 max path length 9
# generating: 14101 goal: 1000000 max path length 9
# generating: 14131 goal: 1000000 max path length 9
# generating: 14157 goal: 1000000 max path length 9
# generating: 14174 goal: 1000000 max path length 9
# generating: 14189 goal: 1000000 max path length 9
# generating: 14202 goal: 1000000 max path length 9
# generating: 14210 goal: 1000000 max path length 9
# generating: 14226 goal: 1000000 max path length 9
# generating: 14257 goal: 1000000 max path length 9
# generating: 14280 goal: 1000000 max path length 9
# generating: 14300 goal: 1000000 max path length 9
# generating: 14326 goal: 1000000 max path length 9
# generating: 14363 goal: 1000000 max path length 9
# generating: 14384 goal: 1000000 max path length 9
# generating: 14411 goal: 1000000 max path length 9
# generating: 14432 goal: 1000000 max path length 9
# generating: 14454 goal: 1000000 max path length 9
# generating: 14482 goal: 1000000 max path length 9
# generating: 14497 goal: 1000000 max path length 9
# generating: 14525 goal: 1000000 max path length 9
# generating: 14537 goal: 1000000 max path length 9
# generating: 14555 goal: 1000000 max path length 9
# generating: 14579 goal: 1000000 max path length 9
# generating: 14606 goal: 1000000 max path length 9
# generating: 14626 goal: 1000000 max path length 9
# generating: 14648 goal: 1000000 max path length 9
# generating: 14661 goal: 1000000 max path length 9
# generating: 14678 goal: 1000000 max path length 9
# generating: 14699 goal: 1000000 max path length 9
# generating: 14725 goal: 1000000 max path length 9
# generating: 14750 goal: 1000000 max path length 9
# generating: 14771 goal: 1000000 max path length 9
# generating: 14789 goal: 1000000 max path length 9
# generating: 14812 goal: 1000000 max path length 9
# generating: 14821 goal: 1000000 max path length 9
# generating: 14847 goal: 1000000 max path length 9
# generating: 14877 goal: 1000000 max path length 9
# generating: 14894 goal: 1000000 max path length 9
# generating: 14919 goal: 1000000 max path length 9
# generating: 14934 goal: 1000000 max path length 9
# generating: 14961 goal: 1000000 max path length 9
# generating: 14973 goal: 1000000 max path length 9
# generating: 14989 goal: 1000000 max path length 9
# generating: 15015 goal: 1000000 max path length 9
# generating: 15022 goal: 1000000 max path length 9
# generating: 15048 goal: 1000000 max path length 9
# generating: 15069 goal: 1000000 max path length 9
# generating: 15081 goal: 1000000 max path length 9
# generating: 15113 goal: 1000000 max path length 9
# generating: 15136 goal: 1000000 max path length 9
# generating: 15158 goal: 1000000 max path length 9
# generating: 15192 goal: 1000000 max path length 9
# generating: 15221 goal: 1000000 max path length 9
# generating: 15238 goal: 1000000 max path length 9
# generating: 15252 goal: 1000000 max path length 9
# generating: 15275 goal: 1000000 max path length 9
# generating: 15289 goal: 1000000 max path length 9
# generating: 15316 goal: 1000000 max path length 9
# generating: 15341 goal: 1000000 max path length 9
# generating: 15360 goal: 1000000 max path length 9
# generating: 15381 goal: 1000000 max path length 9
# generating: 15403 goal: 1000000 max path length 9
# generating: 15439 goal: 1000000 max path length 9
# generating: 15460 goal: 1000000 max path length 9
# generating: 15479 goal: 1000000 max path length 9
# generating: 15503 goal: 1000000 max path length 9
# generating: 15525 goal: 1000000 max path length 9
# generating: 15547 goal: 1000000 max path length 9
# generating: 15572 goal: 1000000 max path length 9
# generating: 15593 goal: 1000000 max path length 9
# generating: 15614 goal: 1000000 max path length 9
# generating: 15643 goal: 1000000 max path length 9
# generating: 15665 goal: 1000000 max path length 9
# generating: 15680 goal: 1000000 max path length 9
# generating: 15707 goal: 1000000 max path length 9
# generating: 15741 goal: 1000000 max path length 9
# generating: 15756 goal: 1000000 max path length 9
# generating: 15778 goal: 1000000 max path length 9
# generating: 15798 goal: 1000000 max path length 9
# generating: 15823 goal: 1000000 max path length 9
# generating: 15843 goal: 1000000 max path length 9
# generating: 15856 goal: 1000000 max path length 9
# generating: 15884 goal: 1000000 max path length 9
# generating: 15909 goal: 1000000 max path length 9
# generating: 15914 goal: 1000000 max path length 9
# generating: 15941 goal: 1000000 max path length 9
# generating: 15966 goal: 1000000 max path length 9
# generating: 15986 goal: 1000000 max path length 9
# generating: 16005 goal: 1000000 max path length 9
# generating: 16026 goal: 1000000 max path length 9
# generating: 16044 goal: 1000000 max path length 9
# generating: 16070 goal: 1000000 max path length 9
# generating: 16097 goal: 1000000 max path length 9
# generating: 16118 goal: 1000000 max path length 9
# generating: 16139 goal: 1000000 max path length 9
# generating: 16159 goal: 1000000 max path length 9
# generating: 16187 goal: 1000000 max path length 9
# generating: 16207 goal: 1000000 max path length 9
# generating: 16217 goal: 1000000 max path length 9
# generating: 16240 goal: 1000000 max path length 9
# generating: 16263 goal: 1000000 max path length 9
# generating: 16290 goal: 1000000 max path length 9
# generating: 16311 goal: 1000000 max path length 9
# generating: 16337 goal: 1000000 max path length 9
# generating: 16355 goal: 1000000 max path length 9
# generating: 16390 goal: 1000000 max path length 9
# generating: 16400 goal: 1000000 max path length 9
# generating: 16423 goal: 1000000 max path length 9
# generating: 16440 goal: 1000000 max path length 9
# generating: 16454 goal: 1000000 max path length 9
# generating: 16466 goal: 1000000 max path length 9
# generating: 16487 goal: 1000000 max path length 9
# generating: 16514 goal: 1000000 max path length 9
# generating: 16538 goal: 1000000 max path length 9
# generating: 16555 goal: 1000000 max path length 9
# generating: 16576 goal: 1000000 max path length 9
# generating: 16601 goal: 1000000 max path length 9
# generating: 16622 goal: 1000000 max path length 9
# generating: 16641 goal: 1000000 max path length 9
# generating: 16654 goal: 1000000 max path length 9
# generating: 16674 goal: 1000000 max path length 9
# generating: 16686 goal: 1000000 max path length 9
# generating: 16706 goal: 1000000 max path length 9
# generating: 16724 goal: 1000000 max path length 9
# generating: 16748 goal: 1000000 max path length 9
# generating: 16765 goal: 1000000 max path length 9
# generating: 16789 goal: 1000000 max path length 9
# generating: 16802 goal: 1000000 max path length 9
# generating: 16821 goal: 1000000 max path length 9
# generating: 16857 goal: 1000000 max path length 9
# generating: 16876 goal: 1000000 max path length 9
# generating: 16890 goal: 1000000 max path length 9
# generating: 16919 goal: 1000000 max path length 9
# generating: 16934 goal: 1000000 max path length 9
# generating: 16950 goal: 1000000 max path length 9
# generating: 16968 goal: 1000000 max path length 9
# generating: 16993 goal: 1000000 max path length 9
# generating: 17015 goal: 1000000 max path length 9
# generating: 17033 goal: 1000000 max path length 9
# generating: 17047 goal: 1000000 max path length 9
# generating: 17059 goal: 1000000 max path length 9
# generating: 17087 goal: 1000000 max path length 9
# generating: 17101 goal: 1000000 max path length 9
# generating: 17118 goal: 1000000 max path length 9
# generating: 17132 goal: 1000000 max path length 9
# generating: 17152 goal: 1000000 max path length 9
# generating: 17180 goal: 1000000 max path length 9
# generating: 17211 goal: 1000000 max path length 9
# generating: 17233 goal: 1000000 max path length 9
# generating: 17255 goal: 1000000 max path length 9
# generating: 17281 goal: 1000000 max path length 9
# generating: 17305 goal: 1000000 max path length 9
# generating: 17327 goal: 1000000 max path length 9
# generating: 17345 goal: 1000000 max path length 9
# generating: 17371 goal: 1000000 max path length 9
# generating: 17406 goal: 1000000 max path length 9
# generating: 17431 goal: 1000000 max path length 9
# generating: 17458 goal: 1000000 max path length 9
# generating: 17481 goal: 1000000 max path length 9
# generating: 17491 goal: 1000000 max path length 9
# generating: 17501 goal: 1000000 max path length 9
# generating: 17518 goal: 1000000 max path length 9
# generating: 17537 goal: 1000000 max path length 9
# generating: 17556 goal: 1000000 max path length 9
# generating: 17578 goal: 1000000 max path length 9
# generating: 17591 goal: 1000000 max path length 9
# generating: 17611 goal: 1000000 max path length 9
# generating: 17634 goal: 1000000 max path length 9
# generating: 17664 goal: 1000000 max path length 9
# generating: 17689 goal: 1000000 max path length 9
# generating: 17707 goal: 1000000 max path length 9
# generating: 17730 goal: 1000000 max path length 9
# generating: 17756 goal: 1000000 max path length 9
# generating: 17789 goal: 1000000 max path length 9
# generating: 17811 goal: 1000000 max path length 9
# generating: 17826 goal: 1000000 max path length 9
# generating: 17845 goal: 1000000 max path length 9
# generating: 17867 goal: 1000000 max path length 9
# generating: 17888 goal: 1000000 max path length 9
# generating: 17911 goal: 1000000 max path length 9
# generating: 17932 goal: 1000000 max path length 9
# generating: 17951 goal: 1000000 max path length 9
# generating: 17969 goal: 1000000 max path length 9
# generating: 17992 goal: 1000000 max path length 9
# generating: 18007 goal: 1000000 max path length 9
# generating: 18028 goal: 1000000 max path length 9
# generating: 18040 goal: 1000000 max path length 9
# generating: 18059 goal: 1000000 max path length 9
# generating: 18080 goal: 1000000 max path length 9
# generating: 18096 goal: 1000000 max path length 9
# generating: 18108 goal: 1000000 max path length 9
# generating: 18138 goal: 1000000 max path length 9
# generating: 18158 goal: 1000000 max path length 9
# generating: 18171 goal: 1000000 max path length 9
# generating: 18188 goal: 1000000 max path length 9
# generating: 18214 goal: 1000000 max path length 9
# generating: 18241 goal: 1000000 max path length 9
# generating: 18263 goal: 1000000 max path length 9
# generating: 18286 goal: 1000000 max path length 9
# generating: 18306 goal: 1000000 max path length 9
# generating: 18326 goal: 1000000 max path length 9
# generating: 18345 goal: 1000000 max path length 9
# generating: 18352 goal: 1000000 max path length 9
# generating: 18372 goal: 1000000 max path length 9
# generating: 18393 goal: 1000000 max path length 9
# generating: 18410 goal: 1000000 max path length 9
# generating: 18434 goal: 1000000 max path length 9
# generating: 18453 goal: 1000000 max path length 9
# generating: 18487 goal: 1000000 max path length 9
# generating: 18503 goal: 1000000 max path length 9
# generating: 18523 goal: 1000000 max path length 9
# generating: 18555 goal: 1000000 max path length 9
# generating: 18574 goal: 1000000 max path length 9
# generating: 18586 goal: 1000000 max path length 9
# generating: 18610 goal: 1000000 max path length 9
# generating: 18637 goal: 1000000 max path length 9
# generating: 18665 goal: 1000000 max path length 9
# generating: 18687 goal: 1000000 max path length 9
# generating: 18702 goal: 1000000 max path length 9
# generating: 18728 goal: 1000000 max path length 9
# generating: 18754 goal: 1000000 max path length 9
# generating: 18771 goal: 1000000 max path length 9
# generating: 18786 goal: 1000000 max path length 9
# generating: 18804 goal: 1000000 max path length 9
# generating: 18826 goal: 1000000 max path length 9
# generating: 18846 goal: 1000000 max path length 9
# generating: 18860 goal: 1000000 max path length 9
# generating: 18880 goal: 1000000 max path length 9
# generating: 18894 goal: 1000000 max path length 9
# generating: 18916 goal: 1000000 max path length 9
# generating: 18942 goal: 1000000 max path length 9
# generating: 18974 goal: 1000000 max path length 9
# generating: 18992 goal: 1000000 max path length 9
# generating: 19013 goal: 1000000 max path length 9
# generating: 19031 goal: 1000000 max path length 9
# generating: 19052 goal: 1000000 max path length 9
# generating: 19071 goal: 1000000 max path length 9
# generating: 19089 goal: 1000000 max path length 9
# generating: 19103 goal: 1000000 max path length 9
# generating: 19122 goal: 1000000 max path length 9
# generating: 19146 goal: 1000000 max path length 9
# generating: 19164 goal: 1000000 max path length 9
# generating: 19177 goal: 1000000 max path length 9
# generating: 19197 goal: 1000000 max path length 9
# generating: 19227 goal: 1000000 max path length 9
# generating: 19253 goal: 1000000 max path length 9
# generating: 19269 goal: 1000000 max path length 9
# generating: 19287 goal: 1000000 max path length 9
# generating: 19307 goal: 1000000 max path length 9
# generating: 19325 goal: 1000000 max path length 9
# generating: 19354 goal: 1000000 max path length 9
# generating: 19375 goal: 1000000 max path length 9
# generating: 19391 goal: 1000000 max path length 9
# generating: 19416 goal: 1000000 max path length 9
# generating: 19430 goal: 1000000 max path length 9
# generating: 19457 goal: 1000000 max path length 9
# generating: 19488 goal: 1000000 max path length 9
# generating: 19515 goal: 1000000 max path length 9
# generating: 19533 goal: 1000000 max path length 9
# generating: 19556 goal: 1000000 max path length 9
# generating: 19568 goal: 1000000 max path length 9
# generating: 19586 goal: 1000000 max path length 9
# generating: 19617 goal: 1000000 max path length 9
# generating: 19633 goal: 1000000 max path length 9
# generating: 19649 goal: 1000000 max path length 9
# generating: 19676 goal: 1000000 max path length 9
# generating: 19691 goal: 1000000 max path length 9
# generating: 19704 goal: 1000000 max path length 9
# generating: 19722 goal: 1000000 max path length 9
# generating: 19739 goal: 1000000 max path length 9
# generating: 19763 goal: 1000000 max path length 9
# generating: 19784 goal: 1000000 max path length 9
# generating: 19803 goal: 1000000 max path length 9
# generating: 19826 goal: 1000000 max path length 9
# generating: 19845 goal: 1000000 max path length 9
# generating: 19856 goal: 1000000 max path length 9
# generating: 19875 goal: 1000000 max path length 9
# generating: 19888 goal: 1000000 max path length 9
# generating: 19916 goal: 1000000 max path length 9
# generating: 19944 goal: 1000000 max path length 9
# generating: 19961 goal: 1000000 max path length 9
# generating: 19977 goal: 1000000 max path length 9
# generating: 19993 goal: 1000000 max path length 9
# generating: 20012 goal: 1000000 max path length 9
# generating: 20040 goal: 1000000 max path length 9
# generating: 20059 goal: 1000000 max path length 9
# generating: 20081 goal: 1000000 max path length 9
# generating: 20102 goal: 1000000 max path length 9
# generating: 20129 goal: 1000000 max path length 9
# generating: 20159 goal: 1000000 max path length 9
# generating: 20175 goal: 1000000 max path length 9
# generating: 20204 goal: 1000000 max path length 9
# generating: 20232 goal: 1000000 max path length 9
# generating: 20257 goal: 1000000 max path length 9
# generating: 20280 goal: 1000000 max path length 9
# generating: 20299 goal: 1000000 max path length 9
# generating: 20333 goal: 1000000 max path length 9
# generating: 20361 goal: 1000000 max path length 9
# generating: 20385 goal: 1000000 max path length 9
# generating: 20404 goal: 1000000 max path length 9
# generating: 20424 goal: 1000000 max path length 9
# generating: 20448 goal: 1000000 max path length 9
# generating: 20465 goal: 1000000 max path length 9
# generating: 20478 goal: 1000000 max path length 9
# generating: 20497 goal: 1000000 max path length 9
# generating: 20508 goal: 1000000 max path length 9
# generating: 20533 goal: 1000000 max path length 9
# generating: 20549 goal: 1000000 max path length 9
# ...
# generating: 993397 goal: 1000000 max path length 9
# generating: 993418 goal: 1000000 max path length 9
# generating: 993436 goal: 1000000 max path length 9
# generating: 993452 goal: 1000000 max path length 9
# generating: 993478 goal: 1000000 max path length 9
# generating: 993500 goal: 1000000 max path length 9
# generating: 993514 goal: 1000000 max path length 9
# generating: 993537 goal: 1000000 max path length 9
# generating: 993556 goal: 1000000 max path length 9
# generating: 993570 goal: 1000000 max path length 9
# generating: 993587 goal: 1000000 max path length 9
# generating: 993605 goal: 1000000 max path length 9
# generating: 993629 goal: 1000000 max path length 9
# generating: 993646 goal: 1000000 max path length 9
# generating: 993670 goal: 1000000 max path length 9
# generating: 993695 goal: 1000000 max path length 9
# generating: 993718 goal: 1000000 max path length 9
# generating: 993735 goal: 1000000 max path length 9
# generating: 993753 goal: 1000000 max path length 9
# generating: 993777 goal: 1000000 max path length 9
# generating: 993797 goal: 1000000 max path length 9
# generating: 993827 goal: 1000000 max path length 9
# generating: 993846 goal: 1000000 max path length 9
# generating: 993860 goal: 1000000 max path length 9
# generating: 993885 goal: 1000000 max path length 9
# generating: 993915 goal: 1000000 max path length 9
# generating: 993928 goal: 1000000 max path length 9
# generating: 993947 goal: 1000000 max path length 9
# generating: 993971 goal: 1000000 max path length 9
# generating: 993986 goal: 1000000 max path length 9
# generating: 994012 goal: 1000000 max path length 9
# generating: 994037 goal: 1000000 max path length 9
# generating: 994070 goal: 1000000 max path length 9
# generating: 994097 goal: 1000000 max path length 9
# generating: 994121 goal: 1000000 max path length 9
# generating: 994142 goal: 1000000 max path length 9
# generating: 994170 goal: 1000000 max path length 9
# generating: 994198 goal: 1000000 max path length 9
# generating: 994222 goal: 1000000 max path length 9
# generating: 994248 goal: 1000000 max path length 9
# generating: 994264 goal: 1000000 max path length 9
# generating: 994285 goal: 1000000 max path length 9
# generating: 994304 goal: 1000000 max path length 9
# generating: 994328 goal: 1000000 max path length 9
# generating: 994346 goal: 1000000 max path length 9
# generating: 994373 goal: 1000000 max path length 9
# generating: 994396 goal: 1000000 max path length 9
# generating: 994419 goal: 1000000 max path length 9
# generating: 994438 goal: 1000000 max path length 9
# generating: 994446 goal: 1000000 max path length 9
# generating: 994461 goal: 1000000 max path length 9
# generating: 994477 goal: 1000000 max path length 9
# generating: 994495 goal: 1000000 max path length 9
# generating: 994520 goal: 1000000 max path length 9
# generating: 994548 goal: 1000000 max path length 9
# generating: 994568 goal: 1000000 max path length 9
# generating: 994594 goal: 1000000 max path length 9
# generating: 994610 goal: 1000000 max path length 9
# generating: 994637 goal: 1000000 max path length 9
# generating: 994652 goal: 1000000 max path length 9
# generating: 994675 goal: 1000000 max path length 9
# generating: 994707 goal: 1000000 max path length 9
# generating: 994732 goal: 1000000 max path length 9
# generating: 994753 goal: 1000000 max path length 9
# generating: 994771 goal: 1000000 max path length 9
# generating: 994790 goal: 1000000 max path length 9
# generating: 994811 goal: 1000000 max path length 9
# generating: 994835 goal: 1000000 max path length 9
# generating: 994856 goal: 1000000 max path length 9
# generating: 994884 goal: 1000000 max path length 9
# generating: 994908 goal: 1000000 max path length 9
# generating: 994927 goal: 1000000 max path length 9
# generating: 994953 goal: 1000000 max path length 9
# generating: 994961 goal: 1000000 max path length 9
# generating: 994983 goal: 1000000 max path length 9
# generating: 994991 goal: 1000000 max path length 9
# generating: 995016 goal: 1000000 max path length 9
# generating: 995038 goal: 1000000 max path length 9
# generating: 995052 goal: 1000000 max path length 9
# generating: 995077 goal: 1000000 max path length 9
# generating: 995102 goal: 1000000 max path length 9
# generating: 995124 goal: 1000000 max path length 9
# generating: 995147 goal: 1000000 max path length 9
# generating: 995185 goal: 1000000 max path length 9
# generating: 995206 goal: 1000000 max path length 9
# generating: 995229 goal: 1000000 max path length 9
# generating: 995249 goal: 1000000 max path length 9
# generating: 995266 goal: 1000000 max path length 9
# generating: 995288 goal: 1000000 max path length 9
# generating: 995308 goal: 1000000 max path length 9
# generating: 995324 goal: 1000000 max path length 9
# generating: 995350 goal: 1000000 max path length 9
# generating: 995373 goal: 1000000 max path length 9
# generating: 995396 goal: 1000000 max path length 9
# generating: 995410 goal: 1000000 max path length 9
# generating: 995427 goal: 1000000 max path length 9
# generating: 995445 goal: 1000000 max path length 9
# generating: 995465 goal: 1000000 max path length 9
# generating: 995481 goal: 1000000 max path length 9
# generating: 995507 goal: 1000000 max path length 9
# generating: 995536 goal: 1000000 max path length 9
# generating: 995560 goal: 1000000 max path length 9
# generating: 995583 goal: 1000000 max path length 9
# generating: 995601 goal: 1000000 max path length 9
# generating: 995629 goal: 1000000 max path length 9
# generating: 995661 goal: 1000000 max path length 9
# generating: 995677 goal: 1000000 max path length 9
# generating: 995698 goal: 1000000 max path length 9
# generating: 995719 goal: 1000000 max path length 9
# generating: 995729 goal: 1000000 max path length 9
# generating: 995745 goal: 1000000 max path length 9
# generating: 995768 goal: 1000000 max path length 9
# generating: 995786 goal: 1000000 max path length 9
# generating: 995808 goal: 1000000 max path length 9
# generating: 995821 goal: 1000000 max path length 9
# generating: 995839 goal: 1000000 max path length 9
# generating: 995850 goal: 1000000 max path length 9
# generating: 995882 goal: 1000000 max path length 9
# generating: 995912 goal: 1000000 max path length 9
# generating: 995941 goal: 1000000 max path length 9
# generating: 995971 goal: 1000000 max path length 9
# generating: 995996 goal: 1000000 max path length 9
# generating: 996026 goal: 1000000 max path length 9
# generating: 996047 goal: 1000000 max path length 9
# generating: 996066 goal: 1000000 max path length 9
# generating: 996085 goal: 1000000 max path length 9
# generating: 996098 goal: 1000000 max path length 9
# generating: 996113 goal: 1000000 max path length 9
# generating: 996124 goal: 1000000 max path length 9
# generating: 996142 goal: 1000000 max path length 9
# generating: 996157 goal: 1000000 max path length 9
# generating: 996178 goal: 1000000 max path length 9
# generating: 996193 goal: 1000000 max path length 9
# generating: 996210 goal: 1000000 max path length 9
# generating: 996236 goal: 1000000 max path length 9
# generating: 996260 goal: 1000000 max path length 9
# generating: 996277 goal: 1000000 max path length 9
# generating: 996303 goal: 1000000 max path length 9
# generating: 996328 goal: 1000000 max path length 9
# generating: 996345 goal: 1000000 max path length 9
# generating: 996373 goal: 1000000 max path length 9
# generating: 996395 goal: 1000000 max path length 9
# generating: 996416 goal: 1000000 max path length 9
# generating: 996448 goal: 1000000 max path length 9
# generating: 996475 goal: 1000000 max path length 9
# generating: 996497 goal: 1000000 max path length 9
# generating: 996508 goal: 1000000 max path length 9
# generating: 996523 goal: 1000000 max path length 9
# generating: 996549 goal: 1000000 max path length 9
# generating: 996569 goal: 1000000 max path length 9
# generating: 996588 goal: 1000000 max path length 9
# generating: 996608 goal: 1000000 max path length 9
# generating: 996629 goal: 1000000 max path length 9
# generating: 996654 goal: 1000000 max path length 9
# generating: 996670 goal: 1000000 max path length 9
# generating: 996687 goal: 1000000 max path length 9
# generating: 996706 goal: 1000000 max path length 9
# generating: 996734 goal: 1000000 max path length 9
# generating: 996755 goal: 1000000 max path length 9
# generating: 996773 goal: 1000000 max path length 9
# generating: 996788 goal: 1000000 max path length 9
# generating: 996808 goal: 1000000 max path length 9
# generating: 996828 goal: 1000000 max path length 9
# generating: 996839 goal: 1000000 max path length 9
# generating: 996866 goal: 1000000 max path length 9
# generating: 996889 goal: 1000000 max path length 9
# generating: 996907 goal: 1000000 max path length 9
# generating: 996930 goal: 1000000 max path length 9
# generating: 996949 goal: 1000000 max path length 9
# generating: 996962 goal: 1000000 max path length 9
# generating: 996983 goal: 1000000 max path length 9
# generating: 997006 goal: 1000000 max path length 9
# generating: 997032 goal: 1000000 max path length 9
# generating: 997059 goal: 1000000 max path length 9
# generating: 997079 goal: 1000000 max path length 9
# generating: 997104 goal: 1000000 max path length 9
# generating: 997121 goal: 1000000 max path length 9
# generating: 997143 goal: 1000000 max path length 9
# generating: 997173 goal: 1000000 max path length 9
# generating: 997190 goal: 1000000 max path length 9
# generating: 997207 goal: 1000000 max path length 9
# generating: 997222 goal: 1000000 max path length 9
# generating: 997243 goal: 1000000 max path length 9
# generating: 997261 goal: 1000000 max path length 9
# generating: 997275 goal: 1000000 max path length 9
# generating: 997302 goal: 1000000 max path length 9
# generating: 997320 goal: 1000000 max path length 9
# generating: 997354 goal: 1000000 max path length 9
# generating: 997390 goal: 1000000 max path length 9
# generating: 997420 goal: 1000000 max path length 9
# generating: 997438 goal: 1000000 max path length 9
# generating: 997457 goal: 1000000 max path length 9
# generating: 997491 goal: 1000000 max path length 9
# generating: 997514 goal: 1000000 max path length 9
# generating: 997540 goal: 1000000 max path length 9
# generating: 997566 goal: 1000000 max path length 9
# generating: 997593 goal: 1000000 max path length 9
# generating: 997610 goal: 1000000 max path length 9
# generating: 997633 goal: 1000000 max path length 9
# generating: 997649 goal: 1000000 max path length 9
# generating: 997683 goal: 1000000 max path length 9
# generating: 997698 goal: 1000000 max path length 9
# generating: 997718 goal: 1000000 max path length 9
# generating: 997736 goal: 1000000 max path length 9
# generating: 997757 goal: 1000000 max path length 9
# generating: 997787 goal: 1000000 max path length 9
# generating: 997813 goal: 1000000 max path length 9
# generating: 997830 goal: 1000000 max path length 9
# generating: 997855 goal: 1000000 max path length 9
# generating: 997879 goal: 1000000 max path length 9
# generating: 997903 goal: 1000000 max path length 9
# generating: 997925 goal: 1000000 max path length 9
# generating: 997947 goal: 1000000 max path length 9
# generating: 997969 goal: 1000000 max path length 9
# generating: 998003 goal: 1000000 max path length 9
# generating: 998027 goal: 1000000 max path length 9
# generating: 998049 goal: 1000000 max path length 9
# generating: 998073 goal: 1000000 max path length 9
# generating: 998092 goal: 1000000 max path length 9
# generating: 998117 goal: 1000000 max path length 9
# generating: 998139 goal: 1000000 max path length 9
# generating: 998155 goal: 1000000 max path length 9
# generating: 998181 goal: 1000000 max path length 9
# generating: 998200 goal: 1000000 max path length 9
# generating: 998221 goal: 1000000 max path length 9
# generating: 998261 goal: 1000000 max path length 9
# generating: 998271 goal: 1000000 max path length 9
# generating: 998290 goal: 1000000 max path length 9
# generating: 998323 goal: 1000000 max path length 9
# generating: 998346 goal: 1000000 max path length 9
# generating: 998359 goal: 1000000 max path length 9
# generating: 998381 goal: 1000000 max path length 9
# generating: 998400 goal: 1000000 max path length 9
# generating: 998421 goal: 1000000 max path length 9
# generating: 998439 goal: 1000000 max path length 9
# generating: 998452 goal: 1000000 max path length 9
# generating: 998477 goal: 1000000 max path length 9
# generating: 998498 goal: 1000000 max path length 9
# generating: 998515 goal: 1000000 max path length 9
# generating: 998554 goal: 1000000 max path length 9
# generating: 998557 goal: 1000000 max path length 9
# generating: 998571 goal: 1000000 max path length 9
# generating: 998593 goal: 1000000 max path length 9
# generating: 998618 goal: 1000000 max path length 9
# generating: 998635 goal: 1000000 max path length 9
# generating: 998664 goal: 1000000 max path length 9
# generating: 998681 goal: 1000000 max path length 9
# generating: 998697 goal: 1000000 max path length 9
# generating: 998721 goal: 1000000 max path length 9
# generating: 998733 goal: 1000000 max path length 9
# generating: 998750 goal: 1000000 max path length 9
# generating: 998759 goal: 1000000 max path length 9
# generating: 998783 goal: 1000000 max path length 9
# generating: 998811 goal: 1000000 max path length 9
# generating: 998834 goal: 1000000 max path length 9
# generating: 998854 goal: 1000000 max path length 9
# generating: 998877 goal: 1000000 max path length 9
# generating: 998889 goal: 1000000 max path length 9
# generating: 998905 goal: 1000000 max path length 9
# generating: 998923 goal: 1000000 max path length 9
# generating: 998942 goal: 1000000 max path length 9
# generating: 998967 goal: 1000000 max path length 9
# generating: 998988 goal: 1000000 max path length 9
# generating: 998997 goal: 1000000 max path length 9
# generating: 999027 goal: 1000000 max path length 9
# generating: 999052 goal: 1000000 max path length 9
# generating: 999072 goal: 1000000 max path length 9
# generating: 999095 goal: 1000000 max path length 9
# generating: 999114 goal: 1000000 max path length 9
# generating: 999137 goal: 1000000 max path length 9
# generating: 999157 goal: 1000000 max path length 9
# generating: 999180 goal: 1000000 max path length 9
# generating: 999202 goal: 1000000 max path length 9
# generating: 999215 goal: 1000000 max path length 9
# generating: 999235 goal: 1000000 max path length 9
# generating: 999262 goal: 1000000 max path length 9
# generating: 999276 goal: 1000000 max path length 9
# generating: 999310 goal: 1000000 max path length 9
# generating: 999326 goal: 1000000 max path length 9
# generating: 999346 goal: 1000000 max path length 9
# generating: 999358 goal: 1000000 max path length 9
# generating: 999390 goal: 1000000 max path length 9
# generating: 999400 goal: 1000000 max path length 9
# generating: 999420 goal: 1000000 max path length 9
# generating: 999449 goal: 1000000 max path length 9
# generating: 999471 goal: 1000000 max path length 9
# generating: 999499 goal: 1000000 max path length 9
# generating: 999524 goal: 1000000 max path length 9
# generating: 999537 goal: 1000000 max path length 9
# generating: 999564 goal: 1000000 max path length 9
# generating: 999584 goal: 1000000 max path length 9
# generating: 999610 goal: 1000000 max path length 9
# generating: 999638 goal: 1000000 max path length 9
# generating: 999654 goal: 1000000 max path length 9
# generating: 999668 goal: 1000000 max path length 9
# generating: 999694 goal: 1000000 max path length 9
# generating: 999716 goal: 1000000 max path length 9
# generating: 999734 goal: 1000000 max path length 9
# generating: 999751 goal: 1000000 max path length 9
# generating: 999761 goal: 1000000 max path length 9
# generating: 999776 goal: 1000000 max path length 9
# generating: 999803 goal: 1000000 max path length 9
# generating: 999818 goal: 1000000 max path length 9
# generating: 999831 goal: 1000000 max path length 9
# generating: 999849 goal: 1000000 max path length 9
# generating: 999868 goal: 1000000 max path length 9
# generating: 999902 goal: 1000000 max path length 9
# generating: 999927 goal: 1000000 max path length 9
# generating: 999942 goal: 1000000 max path length 9
# generating: 999956 goal: 1000000 max path length 9
# generating: 999978 goal: 1000000 max path length 9
# generating: 999997 goal: 1000000 max path length 9
# generating: 1000033 goal: 1000000 max path length 9
# max string length 100

# %% [markdown]
# # Step2. Train a hookedtransformer for graph reasoning
# (Note: hookedtransformer is a interpretation tool for LLMs. Learn more about hookedtransformer on TransformerLens. (https://transformerlensorg.github.io/))

# %%
import os
from train_graph_transformer import setup_train_data, setup_model, training
device = 'cuda:0'
n = 10
pattern_name = f'sync{n}'
method = 'path'

n_layer = 5
density = 0.8
edge_remove_density = 0.4
d_hid = 128 # 1536# 768# 192
n_hid = 12
block_size = 128
base_path=f'/egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/'

dataset_path = os.path.join(base_path,'datasets')
eval_interval = 250
log_interval = 250

train_dataset, valid_dataset, tokenizer, vocab_size = setup_train_data(dataset_path, pattern_name, density, edge_remove_density, method)
model, config = setup_model(base_path, vocab_size, n_layer, d_hid, n_hid, pattern_name, method, device, max_length=block_size)
# note: maintain a large batch size in transformer training.
training(base_path, model, config, train_dataset, valid_dataset, tokenizer, device,block_size, max_iters=6000, eval_interval=eval_interval, log_interval=log_interval)
# Out:
# ['<START> 0 5 | 0 7 | 1 4 | 1 6 | 1 5 | 1 3 | 2 5 | 2 3 | 3 6 | 3 8 | 3 4 | 3 7 | 4 6 | 4 7 | 5 3 | 5 1 | 5 2 | 6 1 | 6 7 | 6 4 | 7 3 | 7 9 | 7 8 | 8 0 | 9 8 | 9 6 | 9 7 | 9 5 S 7 E 4 PATH 7 3 4 END_P <END>', '<START> 0 5 | 0 7 | 1 4 | 1 6 | 1 5 | 1 3 | 2 5 | 2 3 | 3 6 | 3 8 | 3 4 | 3 7 | 4 6 | 4 7 | 5 3 | 5 1 | 5 2 | 6 1 | 6 7 | 6 4 | 7 3 | 7 9 | 7 8 | 8 0 | 9 8 | 9 6 | 9 7 | 9 5 S 0 E 4 PATH 0 5 3 4 END_P <END>', '<START> 0 5 | 0 7 | 1 4 | 1 6 | 1 5 | 1 3 | 2 5 | 2 3 | 3 6 | 3 8 | 3 4 | 3 7 | 4 6 | 4 7 | 5 3 | 5 1 | 5 2 | 6 1 | 6 7 | 6 4 | 7 3 | 7 9 | 7 8 | 8 0 | 9 8 | 9 6 | 9 7 | 9 5 S 0 E 4 PATH 0 7 3 4 END_P <END>', '<START> 0 5 | 0 7 | 1 4 | 1 6 | 1 5 | 1 3 | 2 5 | 2 3 | 3 6 | 3 8 | 3 4 | 3 7 | 4 6 | 4 7 | 5 3 | 5 1 | 5 2 | 6 1 | 6 7 | 6 4 | 7 3 | 7 9 | 7 8 | 8 0 | 9 8 | 9 6 | 9 7 | 9 5 S 0 E 4 PATH 0 5 1 4 END_P <END>', '<START> 0 5 | 0 7 | 1 4 | 1 6 | 1 5 | 1 3 | 2 5 | 2 3 | 3 6 | 3 8 | 3 4 | 3 7 | 4 6 | 4 7 | 5 3 | 5 1 | 5 2 | 6 1 | 6 7 | 6 4 | 7 3 | 7 9 | 7 8 | 8 0 | 9 8 | 9 6 | 9 7 | 9 5 S 2 E 9 PATH 2 3 7 9 END_P <END>']
# vocab size:  23 20
# 100%|██████████| 899000/899000 [02:06<00:00, 7117.73it/s]
# 100%|██████████| 100000/100000 [00:11<00:00, 8758.80it/s]
# WARNING:root:d_model 128 is not divisible by d_head 10.n_heads was inferred to be 12, rounding down the ratio.
# 84994982 9454739
# /egr/research-dselab/daixinna/graphghost/simplified_graph_task/train_graph_transformer.py:114: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# Moving model to device:  cuda:0
# num decayed parameter tensors: 47, with 970,248 parameters
# num non-decayed parameter tensors: 38, with 6,679 parameters
# using fused AdamW: True
# 100%|██████████| 15/15 [00:02<00:00,  6.40it/s]
# step 0, val loss 3.875426769256592
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 250: loss 0.5072
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 250, val loss 0.5067379474639893
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 500: loss 0.4879
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 500, val loss 0.4875429570674896
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 750: loss 0.4726
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 750, val loss 0.4730128049850464
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 1000: loss 0.4581
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 1000, val loss 0.4612065851688385
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 1250: loss 0.4538
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 1250, val loss 0.4577392339706421
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 1500: loss 0.4554
# 100%|██████████| 15/15 [00:02<00:00,  6.21it/s]
# step 1500, val loss 0.45343297719955444
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 1750: loss 0.4506
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 1750, val loss 0.45106396079063416
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 2000: loss 0.4473
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 2000, val loss 0.44928914308547974
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 2250: loss 0.4462
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 2250, val loss 0.4470371901988983
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 2500: loss 0.4443
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 2500, val loss 0.44568973779678345
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 2750: loss 0.4437
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 2750, val loss 0.4454593062400818
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 3000: loss 0.4425
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 3000, val loss 0.4448010325431824
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 3250: loss 0.4444
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 3250, val loss 0.44366005063056946
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 3500: loss 0.4417
# 100%|██████████| 15/15 [00:02<00:00,  7.04it/s]
# step 3500, val loss 0.44294247031211853
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 3750: loss 0.4420
# 100%|██████████| 15/15 [00:02<00:00,  7.04it/s]
# step 3750, val loss 0.4425221383571625
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 4000: loss 0.4399
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 4000, val loss 0.44204437732696533
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 4250: loss 0.4398
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 4250, val loss 0.4415353834629059
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 4500: loss 0.4408
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 4500, val loss 0.4418315887451172
# iter 4750: loss 0.4393
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 4750, val loss 0.44077929854393005
# saving checkpoint to /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5
# iter 5000: loss 0.4390
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 5000, val loss 0.4418027997016907
# iter 5250: loss 0.4355
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 5250, val loss 0.44152477383613586
# iter 5500: loss 0.4382
# 100%|██████████| 15/15 [00:02<00:00,  7.03it/s]
# step 5500, val loss 0.4417937099933624
# iter 5750: loss 0.4381
# 100%|██████████| 15/15 [00:02<00:00,  7.04it/s]
# step 5750, val loss 0.44174912571907043
# iter 6000: loss 0.4364
# 100%|██████████| 15/15 [00:02<00:00,  7.04it/s]
# step 6000, val loss 0.4418981373310089

# %% [markdown]
# # Step 3 (Optional) Evaluate the model performance
#
# (Note, the transcoder does not use the result from evaluations, but a good backbone model is more reasonable to be interpreted)

# %%
from eval_graph_transformer import loading, eval

device = 'cuda:0'
base_path=f'/egr/research-dselab/shared/daixinna/graph_reasoning/baby_models'
n_layer = 5
n = 10
pattern_name = f'sync{n}'
method = 'path'
density = 0.8
edge_remove_density = 0.4
d_hid = 128
n_hid = 12
block_size = 128


test_data_set, model, tokenizer, G = loading(base_path, pattern_name, method, density, edge_remove_density, d_hid, n_layer,device)
eval(test_data_set, tokenizer, model,device, G)
# accuracy would achieve 99%
# Out:
# WARNING:root:d_model 128 is not divisible by d_head 10.n_heads was inferred to be 12, rounding down the ratio.
# {'n_layers': 5, 'd_model': 128, 'n_head': 12, 'max_length': 128, 'vocab_size': 23, 'pattern_name': 'sync10', 'method': 'path', 'positions': 'rotary'}
# 128
# Moving model to device:  cuda:0
#   0%|          | 3/1000 [00:00<02:54,  5.71it/s]
# <START> 0 5 | 0 7 | 0 1 | 0 2 | 1 0 | 1 4 | 1 9 | 1 6 | 2 9 | 2 8 | 2 5 | 2 3 | 3 8 | 3 7 | 4 5 | 4 8 | 4 0 | 5 7 | 5 1 | 6 1 | 6 0 | 6 8 | 7 3 | 8 4 | 8 1 | 9 6 | 9 5 | 9 1 S 0 E 8 PATH 0 2 8 END_P <END> <START> 0 5 |
# 100%|██████████| 1000/1000 [01:29<00:00, 11.17it/s]
# acc: 0.998

# %% [markdown]
# # Step4. Train transcoders.
#
# In the [Anthropic blog](https://transformer-circuits.pub/2025/attribution-graphs/biology.html), the authors use cross-layer transcoders. However, training cross-layer transcoders requires substantial computational resources. Therefore, following the open-source implementation from [circuit-tracer](https://github.com/safety-research/circuit-tracer/tree/main), we instead build separate per-layer transcoders as a practical replacement.

# %% [markdown]
# ### 4.1. Load the backbone model and dataset

# %%
from transformer_lens import HookedTransformer, HookedTransformerConfig
from dataclasses import dataclass
import torch
import os
import sys
from abc import ABC
import json
import pickle
from transformers import PreTrainedTokenizerFast
from utils import MyIterableDataset

sys.path.append('../')
from circuit_tracer.configs import Configs
from circuit_tracer.transcoder.activation_functions import JumpReLU, Relu, TopK
from circuit_tracer.transcoder.single_layer_transcoder import SingleLayerTranscoder
from circuit_tracer.transcoder.activations_store import ActivationsStore
from circuit_tracer.transcoder_training import train_sae_on_language_model


def load_defined_model(configs, load_path = None):
    cfg = HookedTransformerConfig(
    n_layers = configs['n_layers'],
    d_model = configs['d_model'],
    d_head = configs['d_model']//configs['n_head'],
    n_ctx = configs['max_length'],
    d_vocab = configs['vocab_size'], # 50257,  
    seed = 42,
    act_fn="gelu", 
    init_mode = 'gpt2',
    positional_embedding_type = configs['positions']
    )
    model = HookedTransformer(cfg) # Assuming you want to load the model on GPU 0
    if load_path is not None:
        state_dict = torch.load(load_path, map_location='cpu')  
        model.load_state_dict(state_dict)
    return model

base_path=f'/egr/research-dselab/shared/daixinna/graph_reasoning/baby_models'
dataset_path = os.path.join(base_path,'datasets')

device = 'cuda:2'
n = 10
pattern_name = f'sync{n}'
method = 'path'
n_layer = 5
density = 0.8
edge_remove_density = 0.4
d_hid = 128 # 1536# 768# 192
n_hid = 12

tokenizer_path = os.path.join(dataset_path, f"{pattern_name}_{method}_baby_tokenizer.json")
base_model_configs_save_path = os.path.join(base_path,f'baby_{pattern_name}_{method}_{n_layer}_{d_hid}_configs.json')
out_dir = os.path.join(base_path, f"models/{pattern_name}_{method}_{n_layer}")
model_path = os.path.join(out_dir, f"{n_layer}_{d_hid}_model_weights.pt")

with open(os.path.join(f'{dataset_path}',f'train_{pattern_name}_{density}_{edge_remove_density}_{method}.pkl'),'rb') as f:
    training_corpus = pickle.load(f)
with open(os.path.join(f'{dataset_path}',f'valid_{pattern_name}_{density}_{edge_remove_density}_{method}.pkl'),'rb') as f:
    valid_corpus = pickle.load(f)

with open(base_model_configs_save_path, "r") as f:
    base_model_configs = json.load(f)
train_dataset_name = f'{pattern_name}_{method}'
tokenizer = PreTrainedTokenizerFast.from_pretrained(tokenizer_path)


train_dataset = MyIterableDataset(training_corpus, tokenizer,stack=True)
valid_dataset = MyIterableDataset(valid_corpus, tokenizer,stack=True)
total_token = train_dataset.token_count
print('loaded train dataset:', len(train_dataset), 'valid dataset:', len(valid_dataset))

model = load_defined_model(base_model_configs, load_path = model_path)
model = model.to(device)
print('loaded model:', model_path)
# Out:
# 100%|██████████| 899000/899000 [02:01<00:00, 7375.58it/s]
# 100%|██████████| 100000/100000 [00:15<00:00, 6555.25it/s]
# WARNING:root:d_model 128 is not divisible by d_head 10.n_heads was inferred to be 12, rounding down the ratio.
# loaded train dataset: 899000 valid dataset: 100000
# Moving model to device:  cuda:2
# loaded model: /egr/research-dselab/shared/daixinna/graph_reasoning/baby_models/models/sync10_path_5/5_128_model_weights.pt

# %% [markdown]
# ### 4.2. Set parameters

# %%
total_training_tokens = 1_000_000 * 20
if total_token < total_training_tokens:
    total_training_tokens = total_token
print('total token:', total_token)

acts_func = 'relu'
transcoder_config = {}
transcoder_config['model_name'] = 'gpt2'
transcoder_config['train_dataset_name'] = train_dataset_name
transcoder_config['dataset_path'] = base_path
transcoder_config['pattern_name'] = pattern_name
transcoder_config['method'] = method
transcoder_config['is_tokenized'] = True
transcoder_config['max_length'] = base_model_configs['max_length']
transcoder_config['total_train_num'] = total_training_tokens
transcoder_config['acts_func'] = acts_func

# turn epoch if the training set is small while MSE still high
transcoder_config['epoch'] = 1
transcoder_config['batch_size'] = 4096
transcoder_config['train_batch_size'] = 4096
transcoder_config['resample_batches'] = 1024
# turn this parameters when out of memory (very efficient)
transcoder_config['n_batches_in_buffer'] = 128
transcoder_config['store_batch_size'] = 32
# turn this parameter to balance the MSE and L1 loss
transcoder_config['l1_coefficient'] = 0.001

# decompose the features to sparse space (can turn the parameters)
transcoder_config['d_transcoder'] = base_model_configs['d_model'] * 2

# large dead feature window is efficient when large vocab size
transcoder_config['dead_feature_window'] = 50
transcoder_config['dead_feature_threshold'] = 1e-8
# do not be too small. Better increasing training num instead of large lr
transcoder_config['lr'] = 1e-3

transcoder_save_path = f'/egr/research-dselab/shared/transcoder_model/{acts_func}_{pattern_name}_{method}_{n_layer}_{d_hid}'
activate_cache_dir = '/egr/research-dselab/shared/daixinna/activations_cache'
if os.path.exists(activate_cache_dir) == False:
    os.makedirs(activate_cache_dir)
if os.path.exists(transcoder_save_path) == False:
    os.makedirs(transcoder_save_path)
# Out:
# total token: 84994982

# %% [markdown]
# ### 4.3. Train transcoder

# %%
for target_layer in range( n_layer):
    configs = Configs.init_setup(target_layer, transcoder_config, base_model_configs, transcoder_save_path, device, activate_cache_dir)
    model = model.to(configs.act_store_device)
    configs.tokenizer_name = None
    if configs.from_pretrained:
        activation_stores = ActivationsStore(configs, model, dataset=train_dataset)
    else:
        activation_stores = ActivationsStore(configs, model, dataset=train_dataset,tokenizer=tokenizer)
    # TODO: we only evaluate on relu function. The others are not been explored.
    if acts_func == 'relu':
        transcoder = SingleLayerTranscoder(configs, Relu())
    if acts_func == 'jump':
        transcoder = SingleLayerTranscoder(configs, JumpReLU(0.0, 0.1))
    if acts_func == 'topk':
        transcoder = SingleLayerTranscoder(configs, TopK( k = 4))

    _, record_scores = train_sae_on_language_model(configs, model, transcoder, activation_stores, use_eval=False)
    print(f"Target Layer: {target_layer}, Record Scores: {record_scores}")
transcoder_cache_dir_config = os.path.join(configs.checkpoint_path, f"{configs.dead_feature_window}_{configs.l1_coefficient}")
if os.path.exists(transcoder_cache_dir_config) is False:
    os.makedirs(transcoder_cache_dir_config, exist_ok=True)
configs.save(os.path.join(transcoder_cache_dir_config,'configs.json'))
# Out:
# Moving model to device:  cuda:2
# /egr/research-dselab/daixinna/graphghost/simplified_graph_task/../circuit_tracer/transcoder/activations_store.py:94: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tokens = torch.tensor(
# 20000000
# Epoch 1/1
# 4882| MSE Loss 0.003 | L1 0.005: : 20000768it [02:17, 145433.91it/s]
# Saved model to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/0.pt
# Model saved to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/0.pt
# Target Layer: 0, Record Scores: {}
# Moving model to device:  cuda:2
# 20000000
# Epoch 1/1
# 4882| MSE Loss 0.006 | L1 0.006: : 20000768it [02:30, 133302.56it/s]
# Saved model to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/1.pt
# Model saved to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/1.pt
# Target Layer: 1, Record Scores: {}
# Moving model to device:  cuda:2
# 20000000
# Epoch 1/1
# 4882| MSE Loss 0.008 | L1 0.007: : 20000768it [02:37, 127194.38it/s]
# Saved model to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/2.pt
# Model saved to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/2.pt
# Target Layer: 2, Record Scores: {}
# Moving model to device:  cuda:2
# 20000000
# Epoch 1/1
# 4882| MSE Loss 0.009 | L1 0.008: : 20000768it [02:46, 120089.03it/s]
# Saved model to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/3.pt
# Model saved to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/3.pt
# Target Layer: 3, Record Scores: {}
# Moving model to device:  cuda:2
# 20000000
# Epoch 1/1
# 4882| MSE Loss 0.011 | L1 0.030: : 20000768it [02:55, 113734.96it/s]
# Saved model to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/4.pt
# Model saved to /egr/research-dselab/shared/transcoder_model/relu_sync10_path_5_128/50_0.001/4.pt
# Target Layer: 4, Record Scores: {}
